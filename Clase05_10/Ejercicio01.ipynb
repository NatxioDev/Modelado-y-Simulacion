# %%
import numpy as np
import math
import random

# m = m = int(input("Ingrese el numero de dias a simular: "))
# n = 31

array_raton = np.array(["B", "E", "E"], ["C", "D", "A"], ["B", "D"], ["C", "B", "E", "E", "G", "G", "G"], ["A", "A", "D", "D", "F", "F"], [ "E", "E","F", "F"], ["D", "D","D", "F", "F","X"])
# array_B = np.array(["C", "D", "A"])
# array_C = np.array(["B", "D"])
# array_D = np.array(["C", "B", "E", "E", "G", "G", "G"])
# array_E = np.array(["A", "A", "D", "D", "F", "F"])
# array_F = np.array([ "E", "E","F", "F"])
# array_G = np.array(["D", "D","D", "F", "F","X"])


# sum_total_hombres = np.array([])
# sum_total_mujeres = np.array([])

print(array_raton)

def getRandom():
    #Beta
    alfa = 0.4
    beta = 0.4
    u = np.array([])
    Y1 = Y2 = 2
    while Y1 + Y2 > 1:
        u1 = random.random()
        u2 = random.random()
        Y1 = u1 ** (1/alfa)
        Y2 = u2 ** (1/beta)
    x = Y1 / (Y1 + Y2)
    # x = round(x,3)
    return x

def sumasDiarias(array):
    cad = ""
    for i, ele in enumerate(array, start=1):
        cad += f"Dia {i}\t"
    cad += "\n"
    for ele in array:
        cad += f"{ele}\t"
    return cad
def obtenerNumero(array, rand, n):
    acum = 0
    for i in range(n):
        if(rand >= acum and rand < array[i]+acum):
            return i
        acum += array[i]

# for i in range(m):
#     sum_dia_hombres = 0
#     sum_dia_mujeres = 0
#     for e in range(n):
#         x1 = obtenerNumero(array_hombres, getRandom(), len(array_hombres))
#         x2 = obtenerNumero(array_mujeres, getRandom(), len(array_mujeres))
#         # x1 = obtenerNumero(array_hombres, random.random(), len(array_hombres))
#         # x2 = obtenerNumero(array_mujeres, random.random(), len(array_mujeres))

#         sum_dia_hombres += x1
#         sum_dia_mujeres += x2

#     sum_total_hombres = np.append(sum_total_hombres, sum_dia_hombres)
#     sum_total_mujeres = np.append(sum_total_mujeres, sum_dia_mujeres)


# print("↓ Sumas diarias ↓")
# print(f"Hombres =>\n{sumasDiarias(sum_total_hombres)}")
# print(f"Mujeres =>\n{sumasDiarias(sum_total_mujeres)}")
# print("↓ Promedios ↓")
# print("Hombres => ",sum_total_hombres.mean())
# print("Mujeres => ",sum_total_mujeres.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-56d7ee416a82> in <module>
#       6 # n = 31
#       7
# ----> 8 array_raton = np.array(["B", "E", "E"], ["C", "D", "A"], ["B", "D"], ["C", "B", "E", "E", "G", "G", "G"], ["A", "A", "D", "D", "F", "F"], [ "E", "E","F", "F"], ["D", "D","D", "F", "F","X"])
#       9 # array_B = np.array(["C", "D", "A"])
#      10 # array_C = np.array(["B", "D"])
#
# TypeError: array() takes from 1 to 2 positional arguments but 7 were given
