# %%
import numpy as np
import math
import pandas as pd

def listarBetas(array, msg):

    print(msg)

    for index, Beta in enumerate(array, start=1):

        print(f'Beta {index} => {Beta}')


n = 8
k = 2
intercepto = 1
bd = pd.read_csv("x06.csv")
bd2 = pd.read_csv("y06.csv")
x = np.matrix(bd)
y = np.matrix(bd2)
xt = x.T
xtx = xt*x
xtxi = np.linalg.inv(xtx)
xtxixt = xtxi*xt
beta = xtxixt*y
lu = (x*xtxi*x.T)
sce = (y.T)*(np.identity(n)-lu)*y
unos = np.ones(n, order='C')
cunos = unos.reshape((n, 1))
cunost = unos.reshape((1, n))
yest = x*beta
lunos = cunos*(1/n)*cunos

if intercepto == 0:
    scr = (y.T)*(lu)*y
    den = sce/(n-k)
else:
    scr = (y.T)*(lu-lunos)*y
    den = sce/(n-k-1)

num = scr/(k)
t = float(den)*xtxi

if intercepto == 1:
    k = k+1

listarBetas(beta, "Betas:")
print()
for i in range(k):
    cof = math.sqrt(float(t[i, i]))
    ts = float(beta[i, 0])/cof
    print(f"Para t[{i}] => {ts}")
    
print(f"\nF de Fischer => {num/den}")
rcuad = float(scr/(scr+sce))
print(f"\nR^2 => {rcuad}")
# Out:
# Betas
# Beta 1 => [[31.8888196]]
# Beta 2 => [[0.34739722]]
# Beta 3 => [[11.76737063]]
#
# Para t[0] => 6.148889474922417
# Para t[1] => 0.03736046768655697
# Para t[2] => 1.7434922257707615
#
# F de Fischer => [[1.6895143]]
#
# R^2 => 0.4032721165326804
