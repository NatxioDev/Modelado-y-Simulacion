# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

TC = 35
TA = 1
k = 0.1
TCArray = np.array([TC])
for i in range(10):

    TC = (TC * (1 - k)) + (k * TA)
    TCArray = np.append(TCArray, TC)

print(TCArray)
plt.plot(TCArray)
# Out:
# [35.         31.6        28.54       25.786      23.3074     21.07666
#  19.068994   17.2620946  15.63588514 14.17229663 12.85506696]
