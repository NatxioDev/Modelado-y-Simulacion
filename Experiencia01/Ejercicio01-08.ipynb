# %% [markdown]
# ## Ejercicio 08
#
# Para el siguiente modelo:
#
# 𝑥𝑡 = 𝑎 𝑥𝑡−1 + 𝑏
#
# Con los siguientes casos:
#
# a) 0<a<1
#
# b) -1<a<0
#
# c) a=1, b≠0
#
# d) a=1, b=0
#
# e) a=0
#
# f) a=-1
#
# g) a>1
#
# h) a<-1
#
# a) Grafique la evolución del sistema. Para cada uno de los puntos usted deberá
# asignar un valor para a o b que cumpla con los criterios.
#
# b) Asignar a cada uno de las evoluciones graficadas una de las siguientes
# descripciones:
#
# a) La secuencia siempre es igual a b
#
# b) Divergente mediante oscilaciones uniformes
#
# c) Convergente mediante fluctuaciones amortiguadas
#
# d) Divergente, función lineal de t con pendiente b.
#
# e) La secuencia siempre es igual al valor de la condición inicial
#
# f) Divergente de forma monótona
#
# g) Divergente mediante oscilaciones explosivas (o exponenciales)
#
# h) Convergente de forma monótona.

# %%
#Ejercicio 08 - Inciso A

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

plt.close("all")
a = 0.5
b = 0
t = 10
x = 100
xarray = np.array([x])


for i in range(t):
    x = (x * a) + b 
    xarray = np.append(xarray, x)

plt.plot(xarray)
#f

# %%
#Ejercicio 08 - Inciso B

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

plt.close("all")
a = -0.5
b = 0
t = 10
x = 1
xarray = np.array([])
for i in range(t):
    xarray = np.append(xarray, x)
    x = (a * x) + b 

plt.plot(xarray)
#g

# %%
#Ejercicio 08 - Inciso C

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

plt.close("all")
a = 1
b = 2
t = 10
x = 1
xarray = np.array([])
for i in range(t):
    xarray = np.append(xarray, x)
    x = (a * x) + b 

plt.plot(xarray)
#d

# %%
#Ejercicio 08 - Inciso D

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

plt.close("all")
a = 1
b = 0
t = 10
x = 20
xarray = np.array([])
for i in range(t):
    xarray = np.append(xarray, x)
    x = (a * x) + b 

plt.plot(xarray)
#e

# %%
#Ejercicio 08 - Inciso E

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

plt.close("all")
a = 0
b = 2
t = 10
x = 1
xarray = np.array([])
for i in range(t):
    xarray = np.append(xarray, x)
    x = (a * x) + b 

plt.plot(xarray)

#a)

# %%
#Ejercicio 08 - Inciso F

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

plt.close("all")
a = -1
b = 0
t = 10
x = 1
xarray = np.array([])
for i in range(t):
    xarray = np.append(xarray, x)
    x = (a * x) + b 

plt.plot(xarray)
#b)

# %%
#Ejercicio 08 - Inciso G

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

plt.close("all")
a = 5
b = 0
t = 10
x = 1
xarray = np.array([])
for i in range(t):
    xarray = np.append(xarray, x)
    x = (a * x) + b 

plt.plot(xarray)
#h

# %%
#Ejercicio 08 - Inciso H

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

plt.close("all")
a = -2
b = 0
t = 10
x = 1
xarray = np.array([])
for i in range(t):
    xarray = np.append(xarray, x)
    x = (a * x) + b 

plt.plot(xarray)
#c
