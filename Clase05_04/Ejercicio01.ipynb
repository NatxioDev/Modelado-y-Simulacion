# %% [markdown]
# Trabajo de aula
#
# Nombre: Yamil Ignacio Paz Sea
#
# ## Distribuciones

# %%
import numpy as np
import pandas as pd
import math


def pruebaChiCuadrado(data, m):
    t = 0
    for ele in data:
        t = t + (((ele-m*(1/len(data)))**2)/(m*(len(data))))
    if t > 6.98:
        print("Se rechaza la hipotesis nula para la chi cuadrado con 95% de confianza")
        print(len(data))
    else:
        print("se acepta la hipotesis nula para chi cuadrado")


data_array = np.array([1, 2, 3, 1, 2, 1, 1, 2, 3, 2,
                       3, 1, 1, 2, 3, 3, 1, 3, 2, 2])
maxim = data_array.max()


data = []
m = 0
for i in range(1,maxim+1):
    x = 0
    for ele in data_array:
        if ele == i:
            x = x + ele

    x = int(x/i)
    m = m+x
    data.append()
    x = 0
pruebaChiCuadrado(data, m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c645a1fa3413> in <module>
#      32     data.append([i, x])
#      33     x = 0
# ---> 34 pruebaChiCuadrado(data, m)
#
# <ipython-input-5-c645a1fa3413> in pruebaChiCuadrado(data, m)
#       7     t = 0
#       8     for ele in data:
# ----> 9         t = t + (((ele-m*(1/len(data)))**2)/(m*(len(data))))
#      10     if t > 6.98:
#      11         print("Se rechaza la hipotesis nula para la chi cuadrado con 95% de confianza")
#
# TypeError: unsupported operand type(s) for -: 'list' and 'float'
